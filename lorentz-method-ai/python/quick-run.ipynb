# %%
# !python main.py --csv "MYX_FCPO1!, 5.csv" --out "MYX_FCPO1!, 5-output.csv"
# Out:
# /home/simkwongwui/personal-scripts/trading-view-ai-assist-main/trading-view-ai-assist/lorentz-method-ai/python/lc/pipeline/ann.py:196: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   is_last_buy = (fs.shift(4) == 1) & ema_up.shift(4).fillna(True) & sma_up.shift(4).fillna(True)
# /home/simkwongwui/personal-scripts/trading-view-ai-assist-main/trading-view-ai-assist/lorentz-method-ai/python/lc/pipeline/ann.py:197: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('MYX_FCPO1!, 5-output.csv')

# %%
df.shape
# Out:
# (2517, 23)

# %%
from lc.pipeline.trade_metrics import evaluate_trades_with_metrics

trades, summary = evaluate_trades_with_metrics(df)
print(trades[["side", "entry_price", "exit_price", "pnl"]])
print(summary)
# Out:
#      side  entry_price  exit_price   pnl
# 0   short       4042.0      4027.0  15.0
# 1    long       4044.0      4048.0   4.0
# 2   short       4036.0      4043.0  -7.0
# 3    long       4029.0      4050.0  21.0
# 4   short       4072.0      4066.0   6.0
# 5    long       4087.0      4090.0   3.0
# 6   short       4073.0      4062.0  11.0
# 7    long       4064.0      4063.0  -1.0
# 8   short       4056.0      4065.0  -9.0
# 9    long       4070.0      4077.0   7.0
# 10  short       4086.0      4085.0   1.0
# 11   long       4084.0      4084.0   0.0
# 12  short       4070.0      4070.0   0.0
# 13   long       4055.0      4062.0   7.0
# 14  short       4005.0      3994.0  11.0
# 15   long       4015.0      4010.0  -5.0
# 16  short       3988.0      3997.0  -9.0
# 17  short       4025.0      4018.0   7.0
# 18   long       4017.0      4011.0  -6.0
# 19  short       4008.0      4022.0 -14.0
# 20   long       4021.0      4030.0   9.0
# 21  short       4020.0      4054.0 -34.0
# ...

# %%
trades.pnl.describe()
# Out:
# count    58.000000
# mean      1.396552
# std      10.602780
# min     -34.000000
# 25%      -5.000000
# 50%       1.000000
# 75%       7.000000
# max      31.000000
# Name: pnl, dtype: float64

# %%
df.columns
# Out:
# Index(['time', 'open', 'high', 'low', 'close', 'volume', 'rsi_14_1',
#        'wt_10_11', 'cci_20_1', 'adx_20_2', 'rsi_9_1', 'kernel_rq_8_8.0_25',
#        'kernel_gauss_8_2_25', 'ema_200', 'sma_200', 'atr_14', 'prediction',
#        'signal', 'start_long', 'start_short', 'end_long', 'end_short',
#        'kernel_estimate'],
#       dtype='object')

# %%
for var in ['start_long', 'start_short', 'end_long', 'end_short']:
    print(df[var].value_counts())
# Out:
# start_long
# False    2482
# True       35
# Name: count, dtype: int64
# start_short
# False    2480
# True       37
# Name: count, dtype: int64
# end_long
# False    2486
# True       31
# Name: count, dtype: int64
# end_short
# False    2484
# True       33
# Name: count, dtype: int64
